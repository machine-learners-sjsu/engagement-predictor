# %% [markdown]
# ### Importing Libraries

# %%
from __future__ import unicode_literals
import youtube_dl
import json
import pandas as pd

# %% [markdown]
# #### Video Extract Information Logic

# %%
def extract_video_information(video_url):
    ydl_opts = {}
    
    try:
        
        with youtube_dl.YoutubeDL(ydl_opts) as ydl:
            video_meta_info = ydl.extract_info(video_url, download=False)

        meta_information = {
            "video_id": "",
            "video_channel_name": "",
            "video_title":  "",
            "video_thumbnail":  "",
            "video_artist":  "",
            "like_count":  "",
            "description":  "",
            "upload_date":   "",
            "uploader":  "",
            "video_duration":  "",
            "view_count":  "",
            "video_rating":  "",
            "video_url":  "",
            "video_category":  "",
            "video_tags":  "",
            "video_like_count":  "",
            "video_creator":  "",
            "video_alt_title":  "",
            "video_age_limit": "",
            "video_channel":  "",
        }


        try:
            meta_information.update({"video_id": video_meta_info["id"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_channel_name": video_meta_info["channel"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_title": video_meta_info["title"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_thumbnail": video_meta_info["thumbnail"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_artist": video_meta_info["artist"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"like_count": video_meta_info["like_count"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"description": video_meta_info["description"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"upload_date": video_meta_info["upload_date"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"uploader": video_meta_info["uploader"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_duration": video_meta_info["video_duration"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"view_count": video_meta_info["view_count"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_rating": video_meta_info["video_rating"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_url": video_meta_info["webpage_url"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_category": video_meta_info["categories"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_tags": video_meta_info["tags"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_like_count": video_meta_info["like_count"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_creator": video_meta_info["creator"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_alt_title": video_meta_info["alt_title"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_age_limit": video_meta_info["age_limit"]})
        except Exception as e:
            print(e)

        try:
            meta_information.update({"video_channel": video_meta_info["channel_url"]})
        except Exception as e:
            print(e)


        return meta_information
    
    except Exception as e:
        print(e)

# %% [markdown]
# #### Importing video ids

# %%
all_video_ids = pd.read_csv("Videos-Id's.csv")

# %%
all_video_ids.shape
# Out:
# (45481, 1)

# %%
records = {}

# %%
for i in range(0, 25000):
    print("****************")
    print(all_video_ids.iloc[i]['video_id'])
    video_id = all_video_ids.iloc[i]['video_id']
    video_url = "https://www.youtube.com/watch?v={video_id}".format(video_id=video_id)
    video_record = extract_video_information(video_url)
    records.update({video_id:video_record})
    print("****************")
# Out:
# ****************
# 2kyS6SvSYSE
# [youtube] 2kyS6SvSYSE: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 1ZAPwfrtAFY
# [youtube] 1ZAPwfrtAFY: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 5qpjK5DgCt4
# [youtube] 5qpjK5DgCt4: Downloading webpage
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Private video
# Sign in if you've been granted access to this video
# ****************
# ****************
# puqaWrEC7tY
# [youtube] puqaWrEC7tY: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# d380meD0W0M
# [youtube] d380meD0W0M: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# gHZ1Qz0KiKM
# [youtube] gHZ1Qz0KiKM: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 39idVpFF7NQ
# [youtube] 39idVpFF7NQ: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# nc99ccSXST0
# [youtube] nc99ccSXST0: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# jr9QtXwC9vc
# [youtube] jr9QtXwC9vc: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# TUmyygCMMGA
# [youtube] TUmyygCMMGA: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 9wRQljFNDW8
# [youtube] 9wRQljFNDW8: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# VifQlJit6A0
# [youtube] VifQlJit6A0: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 5E4ZBSInqUU
# [youtube] 5E4ZBSInqUU: Downloading webpage
# 'video_duration'
# 'video_rating'
# ****************
# ****************
# GgVmn66oK_A
# [youtube] GgVmn66oK_A: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# TaTleo4cOs8
# [youtube] TaTleo4cOs8: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# wRGldR_SQAA
# [youtube] wRGldR_SQAA: Downloading webpage
# ERROR: Video unavailable
# ERROR: Video unavailable
# ****************
# ****************
# agKDPntMv-E
# [youtube] agKDPntMv-E: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# Xl38SuxyrgM
# [youtube] Xl38SuxyrgM: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# u7pV4vxD1bs
# [youtube] u7pV4vxD1bs: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# zYWt2mnalP8
# [youtube] zYWt2mnalP8: Downloading webpage
# ERROR: Video unavailable
# ERROR: Video unavailable
# ****************
# ****************
# PoNWU2cox9w
# [youtube] PoNWU2cox9w: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 6hTzM1BPdU8
# [youtube] 6hTzM1BPdU8: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# MCW5HUkrr-o
# [youtube] MCW5HUkrr-o: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# YvfYK0EEhK4
# [youtube] YvfYK0EEhK4: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# cxMvzK2OQTw
# [youtube] cxMvzK2OQTw: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# bAkEd8r7Nnw
# [youtube] bAkEd8r7Nnw: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# ItYOdWRo0JY
# [youtube] ItYOdWRo0JY: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 5530I_pYjbo
# [youtube] 5530I_pYjbo: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# dUMH6DVYskc
# [youtube] dUMH6DVYskc: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# gjXrm2Q-te4
# [youtube] gjXrm2Q-te4: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 9SK1I0V6U5c
# [youtube] 9SK1I0V6U5c: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# VsYmwBOYfW8
# [youtube] VsYmwBOYfW8: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# CtBca6H6Teg
# [youtube] CtBca6H6Teg: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# pcWKpGzhgq4
# [youtube] pcWKpGzhgq4: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# L3br0klRqF4
# [youtube] L3br0klRqF4: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 9kF9xY74h-E
# [youtube] 9kF9xY74h-E: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# p2EY93WfBQk
# [youtube] p2EY93WfBQk: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# xL_qpDkF5A8
# [youtube] xL_qpDkF5A8: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# eQVhAN7-IAw
# [youtube] eQVhAN7-IAw: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# Y9nDagqKL7Q
# [youtube] Y9nDagqKL7Q: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# DbJ2s_g1oDc
# [youtube] DbJ2s_g1oDc: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# KJ12FVmumeA
# [youtube] KJ12FVmumeA: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# qDAxDcjgn-8
# [youtube] qDAxDcjgn-8: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 815lSYphlbw
# [youtube] 815lSYphlbw: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# E_86MEdNsAI
# [youtube] E_86MEdNsAI: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# Cr9oGxr0Qa0
# [youtube] Cr9oGxr0Qa0: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# g0K5QoEj7FQ
# [youtube] g0K5QoEj7FQ: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# l4bAoNAx2uo
# [youtube] l4bAoNAx2uo: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# TSqwDQHE1J8
# [youtube] TSqwDQHE1J8: Downloading webpage
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Private video
# Sign in if you've been granted access to this video
# ****************
# ****************
# MltuW2kcREI
# [youtube] MltuW2kcREI: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# jGiqc3HSxEg
# [youtube] jGiqc3HSxEg: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# XrDlDj9DfZs
# [youtube] XrDlDj9DfZs: Downloading webpage
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Private video
# Sign in if you've been granted access to this video
# ****************
# ****************
# Z3OZyb2iWqQ
# [youtube] Z3OZyb2iWqQ: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# Hq89wYzOjfs
# [youtube] Hq89wYzOjfs: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# vZzIS17HexE
# [youtube] vZzIS17HexE: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# yZGSIpcAfEo
# [youtube] yZGSIpcAfEo: Downloading webpage
# ERROR: Video unavailable
# ERROR: Video unavailable
# ****************
# ****************
# zxUwbflE1SY
# [youtube] zxUwbflE1SY: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 7oRdswHqaf8
# [youtube] 7oRdswHqaf8: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# qC0I5PEhkJo
# [youtube] qC0I5PEhkJo: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 0zk2SwmCpss
# [youtube] 0zk2SwmCpss: Downloading webpage
# ERROR: Video unavailable
# ERROR: Video unavailable
# ****************
# ****************
# SGVbdo2CkgI
# [youtube] SGVbdo2CkgI: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# NfLVVJOuY5M
# [youtube] NfLVVJOuY5M: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# F388-6yDDpc
# [youtube] F388-6yDDpc: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# KhdecX0qjNA
# [youtube] KhdecX0qjNA: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# kWIzjMWmuYk
# [youtube] kWIzjMWmuYk: Downloading webpage
# [youtube] kWIzjMWmuYk: Downloading MPD manifest
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# symdi5KSJts
# [youtube] symdi5KSJts: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 5hEJsoDP2q4
# [youtube] 5hEJsoDP2q4: Downloading webpage
# 'video_duration'
# 'video_rating'
# ****************
# ****************
# lBHPVE3AI6Y
# [youtube] lBHPVE3AI6Y: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# kIUHDwn51y8
# [youtube] kIUHDwn51y8: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# Lz7dya576HY
# [youtube] Lz7dya576HY: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# kqmhCaF5_44
# [youtube] kqmhCaF5_44: Downloading webpage
# 'video_duration'
# 'video_rating'
# ****************
# ****************
# eAyxMv4IBH8
# [youtube] eAyxMv4IBH8: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# EJu_wPGFTw0
# [youtube] EJu_wPGFTw0: Downloading webpage
# [youtube] EJu_wPGFTw0: Downloading MPD manifest
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# MKLlDnUqho4
# [youtube] MKLlDnUqho4: Downloading webpage
# 'video_duration'
# 'video_rating'
# ****************
# ****************
# wwZ-T_WQ03A
# [youtube] wwZ-T_WQ03A: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# i-LCORFB860
# [youtube] i-LCORFB860: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# vWYyZMH_QjA
# [youtube] vWYyZMH_QjA: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# VJlSq6h0LNg
# [youtube] VJlSq6h0LNg: Downloading webpage
# [youtube] VJlSq6h0LNg: Downloading MPD manifest
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# ijJPFowBsBc
# [youtube] ijJPFowBsBc: Downloading webpage
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Private video
# Sign in if you've been granted access to this video
# ****************
# ****************
# HBS9783c0BI
# [youtube] HBS9783c0BI: Downloading webpage
# ERROR: Private video
# Sign in if you've been granted access to this video
# ERROR: Private video
# Sign in if you've been granted access to this video
# ****************
# ****************
# JwboxqDylgg
# [youtube] JwboxqDylgg: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 1WDj0DddCcM
# [youtube] 1WDj0DddCcM: Downloading webpage
# [youtube] 1WDj0DddCcM: Downloading MPD manifest
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# bqgVB6Vl-lI
# [youtube] bqgVB6Vl-lI: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# ZhSk8mPSWCg
# [youtube] ZhSk8mPSWCg: Downloading webpage
# [youtube] ZhSk8mPSWCg: Downloading MPD manifest
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# qooQd8AA7_M
# [youtube] qooQd8AA7_M: Downloading webpage
# 'video_duration'
# 'video_rating'
# ****************
# ****************
# 9KIP-Ncp2jU
# [youtube] 9KIP-Ncp2jU: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# i4YQRLQVixM
# [youtube] i4YQRLQVixM: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# Fyyua5JzD9w
# [youtube] Fyyua5JzD9w: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 9Th4qTv-4jE
# [youtube] 9Th4qTv-4jE: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# uTH--XRCGxM
# [youtube] uTH--XRCGxM: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# ttf_EzEkxBk
# [youtube] ttf_EzEkxBk: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# l7je4VAUvjA
# [youtube] l7je4VAUvjA: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# 8-Cjsnq8kVU
# [youtube] 8-Cjsnq8kVU: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# hpapqEeb36k
# [youtube] hpapqEeb36k: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# cmoknv58jjE
# [youtube] cmoknv58jjE: Downloading webpage
# 'artist'
# 'video_duration'
# 'video_rating'
# 'creator'
# 'alt_title'
# ****************
# ****************
# sottGW1p5os
# [youtube] sottGW1p5os: Downloading webpage

# %%
records_frame = pd.DataFrame.from_dict(records, orient='columns')

# %%
records_frame= records_frame.T

# %%
records_frame.head(3)

# %%
records_frame.to_csv("Records-First-Batch.csv",index=False)
