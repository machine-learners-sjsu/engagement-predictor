# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ### Data Preparation

# %%
train_videos_dataframe = pd.read_parquet('/Users/aryanjadon/Desktop/Spring-Semester-Projects/Dataset/Video-Statistics/train.parquet')

# %%
train_videos_dataframe.shape
# Out:
# (92275, 20)

# %%
train_videos_dataframe.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#                 publishedAt                 channelId   channelTitle  \
# 0 2020-08-11 19:20:14+00:00  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis
# 1 2020-08-11 17:00:10+00:00  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends
# 2 2020-08-11 16:34:06+00:00  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye
# 3 2020-08-11 16:38:55+00:00  UCbg_UMjlHJg_19SZckaKajg            XXL
# 4 2020-08-11 15:10:05+00:00  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate
#
#    categoryId trending_date  \
# 0          22    2020-08-12
# 1          20    2020-08-12
# 2          24    2020-08-12
# 3          10    2020-08-12
# ...

# %%
all_categories = {
  "1":"Film & Animation",
  "2":"Autos & Vehicles",
  "10":"Music",
  "15":"Pets & Animals",
  "17":"Sports",
  "18":"Short Movies",
  "19":"Travel & Events",
  "20":"Gaming",
  "21":"Videoblogging",
  "22":"People & Blogs",
  "23":"Comedy",
  "24":"Entertainment",
  "25":"News & Politics",
  "26":"How to & Style",
  "27":"Education",
  "28":"Science & Technology",
  "29":"Nonprofits & Activism",
  "30":"Movies",
  "31":"Anime/Animation",
  "32":"Action/Adventure",
  "33":"Classics",
  "34":"Comedy",
  "35":"Documentary",
  "36":"Drama",
  "37":"Family",
  "38":"Foreign",
  "39":"Horror",
  "40":"Sci-Fi/Fantasy",
  "41":"Thriller",
  "42":"Shorts",
  "43":"Shows",
  "44":"Trailers"
  }

# %%
train_videos_dataframe["cateogory_name"] = ""

# %%
for index, row in tqdm(train_videos_dataframe.iterrows(), total=train_videos_dataframe.shape[0]):
    cat_id = row['categoryId']
    cat_name = all_categories[str(cat_id)]
    train_videos_dataframe.at[index,'cateogory_name'] = cat_name
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 92275/92275 [00:10<00:00, 8737.27it/s]

# %%
train_videos_dataframe.head()
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#                 publishedAt                 channelId   channelTitle  \
# 0 2020-08-11 19:20:14+00:00  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis
# 1 2020-08-11 17:00:10+00:00  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends
# 2 2020-08-11 16:34:06+00:00  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye
# 3 2020-08-11 16:38:55+00:00  UCbg_UMjlHJg_19SZckaKajg            XXL
# 4 2020-08-11 15:10:05+00:00  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate
#
#    categoryId trending_date  \
# 0          22    2020-08-12
# 1          20    2020-08-12
# 2          24    2020-08-12
# 3          10    2020-08-12
# ...

# %%
for index, row in tqdm(train_videos_dataframe.iterrows(), total=train_videos_dataframe.shape[0]):
    tags = row['tags']
    train_videos_dataframe.at[index,'tags'] = ",".join(tags.split('|'))
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 92275/92275 [00:11<00:00, 7858.72it/s]

# %%
train_videos_dataframe.head(5)
# Out:
#       video_id                                              title  \
# 0  3C66w5Z0ixs                 I ASKED HER TO BE MY GIRLFRIEND...
# 1  M9Pmf9AB4Mo  Apex Legends | Stories from the Outlands – “Th...
# 2  J78aPJ3VyNs  I left youtube for a month and THIS is what ha...
# 3  kXLn3HkpjaA  XXL 2020 Freshman Class Revealed - Official An...
# 4  VIUo6yapDbc  Ultimate DIY Home Movie Theater for The LaBran...
#
#                 publishedAt                 channelId   channelTitle  \
# 0 2020-08-11 19:20:14+00:00  UCvtRTOMP2TqYqu51xNrqAzg       Brawadis
# 1 2020-08-11 17:00:10+00:00  UC0ZV6M2THA81QT9hrVWJG3A   Apex Legends
# 2 2020-08-11 16:34:06+00:00  UCYzPXprvl5Y-Sf0g4vX-m6g  jacksepticeye
# 3 2020-08-11 16:38:55+00:00  UCbg_UMjlHJg_19SZckaKajg            XXL
# 4 2020-08-11 15:10:05+00:00  UCDVPcEbVLQgLZX0Rt6jo34A       Mr. Kate
#
#    categoryId trending_date  \
# 0          22    2020-08-12
# 1          20    2020-08-12
# 2          24    2020-08-12
# 3          10    2020-08-12
# ...

# %%
test_videos_dataframe = pd.read_parquet('/Users/aryanjadon/Desktop/Spring-Semester-Projects/Dataset/Video-Statistics/test.parquet')

# %%
test_videos_dataframe["cateogory_name"] = ""

for index, row in tqdm(test_videos_dataframe.iterrows(), total=test_videos_dataframe.shape[0]):
    cat_id = row['categoryId']
    cat_name = all_categories[str(cat_id)]
    test_videos_dataframe.at[index,'cateogory_name'] = cat_name

for index, row in tqdm(test_videos_dataframe.iterrows(), total=test_videos_dataframe.shape[0]):
    tags = row['tags']
    test_videos_dataframe.at[index,'tags'] = ",".join(tags.split('|'))
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5800/5800 [00:00<00:00, 8765.70it/s]

# %%
test_videos_dataframe.head(5)
# Out:
#       video_id                                              title  \
# 0  _wNsZEqpKUA  Billie Eilish: Same Interview, The Fifth Year ...
# 1  2jfbXZiE6Lc                     Redneck vs Fancy Whiskey Glass
# 2  F1Hq8eVOMHs                           Is Meat Really that Bad?
# 3  GQXVQmcGQUY  Things Get Strange With The UnderTaker | Cold ...
# 4  n4XojTb6pfs                    People Pleasers at a Restaurant
#
#                 publishedAt                 channelId  \
# 0 2021-11-30 17:00:10+00:00  UCIsbLox_y9dCIMLd8tdC6qg
# 1 2021-11-29 21:30:27+00:00  UCT_QEGH0myu6lgbE_biQPuw
# 2 2021-11-30 15:01:34+00:00  UCsXVk37bltHxD1rDPwtNM8Q
# 3 2021-11-30 16:00:27+00:00  UCLRmIdRJgLfmdpJufmBhBuA
# 4 2021-11-30 17:15:02+00:00  UCT_QEGH0myu6lgbE_biQPuw
#
#                  channelTitle  categoryId trending_date  \
# 0                 Vanity Fair          24    2021-12-01
# 1                Drew Talbert          23    2021-12-01
# 2  Kurzgesagt – In a Nutshell          27    2021-12-01
# ...

# %% [markdown]
# ### Exporting Files

# %%
train_videos_dataframe.to_json (r'train_dataset.json', orient='records')

# %%
test_videos_dataframe.to_json (r'test_dataset.json', orient='records')
